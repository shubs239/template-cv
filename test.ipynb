# %%
# !pip install weasyprint
# Out:
# Collecting weasyprint
#   Using cached weasyprint-66.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydyf>=0.11.0 (from weasyprint)
#   Using cached pydyf-0.11.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: cffi>=0.6 in /home/codespace/.local/lib/python3.12/site-packages (from weasyprint) (1.17.1)
# Collecting tinyhtml5>=2.0.0b1 (from weasyprint)
#   Using cached tinyhtml5-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tinycss2>=1.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from weasyprint) (1.4.0)
# Collecting cssselect2>=0.8.0 (from weasyprint)
#   Using cached cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint)
#   Using cached pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Pillow>=9.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from weasyprint) (11.3.0)
# Requirement already satisfied: fonttools>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from fonttools[woff]>=4.0.0->weasyprint) (4.58.5)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=0.6->weasyprint) (2.22)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.12/site-packages (from cssselect2>=0.8.0->weasyprint) (0.5.1)
# Collecting brotli>=1.0.1 (from fonttools[woff]>=4.0.0->weasyprint)
#   Using cached Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting zopfli>=0.1.4 (from fonttools[woff]>=4.0.0->weasyprint)
#   Using cached zopfli-0.2.3.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Using cached weasyprint-66.0-py3-none-any.whl (301 kB)
# Using cached cssselect2-0.8.0-py3-none-any.whl (15 kB)
# Using cached Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
# Using cached pydyf-0.11.0-py3-none-any.whl (8.1 kB)
# Using cached pyphen-0.17.2-py3-none-any.whl (2.1 MB)
# Using cached tinyhtml5-2.0.0-py3-none-any.whl (39 kB)
# Using cached zopfli-0.2.3.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (851 kB)
# Installing collected packages: brotli, zopfli, tinyhtml5, Pyphen, pydyf, cssselect2, weasyprint
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [weasyprint]7 [weasyprint]
# Successfully installed Pyphen-0.17.2 brotli-1.1.0 cssselect2-0.8.0 pydyf-0.11.0 tinyhtml5-2.0.0 weasyprint-66.0 zopfli-0.2.3.post1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from weasyprint import HTML

# Render HTML with user data
HTML('template.html').write_pdf('output.pdf')
    # print(f"PDF created: {output_pdf_path}")
